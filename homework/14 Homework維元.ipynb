# %% [markdown]
# # [作業目標]
#
#
# 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？
#
# 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %% [markdown]
# # 作業

# %%
# 載入 NumPy, Pandas 套件
import numpy as np
import pandas as pd

# 檢查正確載入與版本
print(np)
print(np.__version__)
print(pd)
print(pd.__version__)
# Out:
# <module 'numpy' from '/opt/anaconda3/lib/python3.7/site-packages/numpy/__init__.py'>
# 1.17.2
# <module 'pandas' from '/opt/anaconda3/lib/python3.7/site-packages/pandas/__init__.py'>
# 0.25.1

# %% [markdown]
# ### 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv')
df1
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df2 = pd.read_csv(
    'https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv',
    keep_default_na=True,
    na_values=['na', '--']
)
df2
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %% [markdown]
# ### 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums')
response = r.text

import json
data = json.loads(response)

# print(data)

df = pd.DataFrame.from_dict(data)
df
# Out:
#                                        id                     alias  \
# 0    7f125e07-4460-4ea5-80b5-33f0e9aafa0c               midnightlab
# 1    c0ed3f99-ed1c-49a8-b413-ed5e925aafe4               timecapsule
# 2    cc2164ae-88cd-466d-b11b-19e4b1f6f78c                    mother
# 3    11e8d941-0aad-4960-8348-b27c36270fd1                 merryxmas
# 4    8d5cabde-d0df-479f-8ab7-153209317537                    father
# ..                                    ...                       ...
# 502  e44b7e81-ff65-4f8c-8c9b-1d411526655b  ragnarokx_nextgeneration
# 503  c8a16de0-b76f-450e-b0b0-29081c27495c             play_together
# 504  495d9eec-0689-44c6-9341-2b96af6bee7a          dead_by_daylight
# 505  0c16b7c5-1c70-4923-9175-ff8041ab2d52                      yoga
# 506  9f2e8e2f-10f4-415f-870b-eaaeb01a9505              luxury_watch
#
#            name                                        description  \
# 0         午夜實驗室  午夜實驗室10/6、10/7即將在華山登場！這裏提供大家交流活動資訊與討論，請大家要遵守 D...
# 1          時光膠囊  Dcard 九週年最終章！告別動盪不安的 2020，說好了，2021 我們一起活得更努力！請...
# 2           母親節                              Dcard 母親節限定板，告訴媽媽我愛妳！
# 3    聖誕CiaoCiao           期間限定開啟！只要是和聖誕節有關的事情，或是和「禮物」有關的東西通通都來分享吧！
# 4           父親節       Dcard 父親節特輯，上傳爸爸帥照，寫下真摯文字，一起謝謝我們心中的 「鋼鐵人老爸」。
# ..          ...                                                ...
# 502   RO：新世代的誕生  ROX看板提供卡友們討論攻略、情報分享、遊戲心得跟詢問RO\n\n仙境傳說：新世代的誕生之相...
# 503       天天玩樂園               本板為《天天玩樂園》板，討論主旨為一切與《天天玩樂園》有關之事物與話題。
# 504        黎明死線                 本板為《黎明死線》板，討論主旨為一切與《黎明死線》有關之事物與話題。
# 505          瑜珈  給熱愛瑜珈、對瑜珈有興趣的同好們，我們一起在相同興趣下努力吧。\n不論瑜珈上的問題或是對瑜珈...
# 506         精品錶                  供討論、分享、詢問與精品錶相關的話題。請大家理性溝通、和平相處喔！
#
#      subscriptionCount  subscribed   read                 createdAt  \
# 0                 1730       False  False  2016-05-14T19:15:15.698Z
# 1                 4269       False  False  2016-05-14T20:15:15.698Z
# 2                  374       False  False  2016-05-14T22:15:15.699Z
# 3                17073       False  False  2016-05-17T00:11:15.742Z
# 4                  367       False  False  2016-05-17T00:12:15.742Z
# ..                 ...         ...    ...                       ...
# 502                 45       False  False  2021-06-24T06:12:55.144Z
# 503                532       False  False  2021-06-25T09:27:38.356Z
# 504                 39       False  False  2021-06-25T09:28:55.547Z
# 505                 17       False  False  2021-06-30T08:46:41.541Z
# 506                 10       False  False  2021-06-30T09:04:50.969Z
#
#                     updatedAt  canPost  ...   nsfw  mediaThreshold  \
# 0    2021-04-20T08:36:58.712Z    False  ...  False              {}
# 1    2021-01-07T07:24:57.455Z    False  ...  False              {}
# 2    2021-04-20T08:36:35.702Z    False  ...  False              {}
# 3    2021-04-20T08:36:54.019Z    False  ...  False              {}
# 4    2017-01-01T10:36:38.235Z    False  ...  False              {}
# ..                        ...      ...  ...    ...             ...
# 502  2021-06-24T06:17:20.796Z    False  ...  False              {}
# 503  2021-06-25T09:37:36.033Z    False  ...  False              {}
# 504  2021-06-25T09:34:56.612Z    False  ...  False              {}
# 505  2021-06-30T09:57:26.256Z    False  ...  False              {}
# 506  2021-06-30T09:04:50.969Z    False  ...  False              {}
#
#      limitCountries  limitStage               availableLayouts  \
# 0                []           0                      [classic]
# 1                []           0                      [classic]
# 2                []           0                      [classic]
# 3                []           0                      [classic]
# 4                []           0                      [classic]
# ..              ...         ...                            ...
# 502              []           0  [classic, image, video, link]
# 503              []           0  [classic, image, video, link]
# 504              []           0  [classic, image, video, link]
# 505              []           0  [classic, image, video, link]
# 506              []           0  [classic, image, video, link]
#
#                postCount  favorite  enablePrivateMessage  \
# 0      {'last30Days': 1}     False                 False
# 1    {'last30Days': 300}     False                 False
# 2      {'last30Days': 1}     False                 False
# 3      {'last30Days': 1}     False                 False
# 4      {'last30Days': 0}     False                 False
# ..                   ...       ...                   ...
# 502    {'last30Days': 9}     False                 False
# 503   {'last30Days': 15}     False                 False
# 504    {'last30Days': 1}     False                 False
# 505    {'last30Days': 0}     False                 False
# 506    {'last30Days': 0}     False                 False
#
#                                              heroImage  \
# 0                                                  NaN
# 1    {'url': 'https://megapx-assets.dcard.tw/images...
# 2                                                  NaN
# 3    {'url': 'https://megapx-assets.dcard.tw/images...
# 4                                                  NaN
# ..                                                 ...
# 502  {'url': 'https://megapx-assets.dcard.tw/images...
# 503  {'url': 'https://megapx-assets.dcard.tw/images...
# 504  {'url': 'https://megapx-assets.dcard.tw/images...
# 505  {'url': 'https://megapx-assets.dcard.tw/images...
# 506                                                NaN
#
#                                                   logo
# 0                                                  NaN
# 1    {'url': 'https://megapx-assets.dcard.tw/images...
# 2                                                  NaN
# 3    {'url': 'https://megapx-assets.dcard.tw/images...
# 4                                                  NaN
# ..                                                 ...
# 502  {'url': 'https://megapx-assets.dcard.tw/images...
# 503  {'url': 'https://megapx-assets.dcard.tw/images...
# 504  {'url': 'https://megapx-assets.dcard.tw/images...
# 505  {'url': 'https://megapx-assets.dcard.tw/images...
# 506                                                NaN
#
# [507 rows x 34 columns]

# %%
df.sort_values(by='subscriptionCount', ascending=False)
# Out:
#                                        id         alias        name  \
# 373  1ce3ebca-8701-42d5-b14c-076fc629bc8e           sex          西斯
# 228  42851318-b9e2-4a75-8a05-9fe180becefe  relationship          感情
# 224  be1a095b-175e-4523-9e06-66a05d939676       dressup          穿搭
# 217  cbd5285f-3cba-4bfc-86d0-1ab52d201459        makeup          美妝
# 233  06e07db4-c8b5-4dae-851f-e8a8236e770c          meme          梗圖
# ..                                    ...           ...         ...
# 208  1150ae79-6e67-46f2-bfec-74f8c365a4a1    hktrending        港澳時事
# 207  019f0994-375e-479a-9b08-1b8addb64cc3      hkbeauty   港澳 Beauty
# 182  9ffbd450-4416-4023-87ef-81b38703a224    hkmacdaily        港澳日常
# 172  9e2ea80f-3342-4533-bb7a-d639e6c517e7       athlete          選手
# 158  d1377288-8432-4ec0-a539-e1ac6d59362c           mkc  馬偕醫護管理專科學校
#
#                                            description  subscriptionCount  \
# 373  西斯板（Sex）提供男女私密話題分享或性教育等情慾議題討論，若有性方面相關問題也可在此發問。...             595516
# 228  無論是遠距離戀愛、情侶間的有趣互動、分手後的藕斷絲連等...都可以在感情板分享你們的愛情故事...             534032
# 224  穿搭板提供各種服裝搭配、包鞋、飾品配件等相關話題討論。\n歡迎分享自己的日常穿搭，或任何潮流...             518596
# 217  不管你喜歡開架彩妝還是專櫃彩妝，美妝板提供各種最新彩妝開箱評比、粉底色號、唇膏試色、眼影試色...             436655
# 233                                            梗圖=有梗的圖             400845
# ..                                                 ...                ...
# 208           呢度係比香港澳門嘅同學仔討論同港澳有關既時事議題嘅討論區，發文留言前請先閱讀板規                  0
# 207    呢度係比香港澳門嘅同學仔討論化妝、護膚、美髮、任何扮靚相關話題嘅討論區，發文留言前請先閱讀板規                  0
# 182          專屬於香港澳門o既討論區，日常生活大小事都可以係度傾～發文請注意需超過15個中文字                  0
# 172                                                                     0
# 158  馬偕醫護管理專科學校板，一個能讓你暢所欲言的地方。在這裡，卡友們可以盡情討論校園裡的大小事，...                  0
#
#      subscribed   read                 createdAt                 updatedAt  \
# 373       False  False  2020-02-04T07:52:53.573Z  2021-06-24T04:50:12.522Z
# 228       False  False  2020-02-04T07:28:43.573Z  2021-04-20T08:36:40.391Z
# 224       False  False  2020-02-04T07:28:03.573Z  2021-04-20T08:36:37.330Z
# 217       False  False  2020-02-04T07:26:53.573Z  2021-06-25T07:07:20.485Z
# 233       False  False  2020-02-04T07:29:33.573Z  2020-08-31T09:47:51.769Z
# ..          ...    ...                       ...                       ...
# 208       False  False  2020-01-02T03:22:36.962Z  2021-04-20T10:31:36.975Z
# 207       False  False  2020-01-02T03:21:28.406Z  2021-04-20T10:15:48.549Z
# 182       False  False  2018-10-03T03:41:18.556Z  2021-04-20T10:09:10.711Z
# 172       False  False  2017-08-22T05:22:03.772Z  2020-08-13T06:02:20.625Z
# 158       False  False  2016-09-23T09:35:46.370Z  2020-08-13T08:58:10.340Z
#
#      canPost  ...   nsfw                          mediaThreshold  \
# 373    False  ...   True  {'RACY': 1, 'ADULT': 1, 'VIOLENCE': 1}
# 228    False  ...  False                                      {}
# 224    False  ...  False                                      {}
# 217    False  ...  False                                      {}
# 233    False  ...  False                                      {}
# ..       ...  ...    ...                                     ...
# 208    False  ...  False                                      {}
# 207    False  ...  False                                      {}
# 182    False  ...  False                                      {}
# 172    False  ...  False                                      {}
# 158    False  ...  False                                      {}
#
#      limitCountries  limitStage               availableLayouts  \
# 373              []           0                      [classic]
# 228              []           0                      [classic]
# 224              []           0                [classic, link]
# 217              []           0                      [classic]
# 233              []           0                        [image]
# ..              ...         ...                            ...
# 208        [HK, MO]           0  [classic, image, video, link]
# 207        [HK, MO]           0  [classic, image, video, link]
# 182        [HK, MO]           0  [classic, image, video, link]
# 172              []           0                [classic, link]
# 158              []           0                [classic, link]
#
#                  postCount  favorite  enablePrivateMessage  \
# 373   {'last30Days': 5631}     False                 False
# 228  {'last30Days': 11363}     False                 False
# 224   {'last30Days': 1317}     False                 False
# 217   {'last30Days': 3065}     False                 False
# 233   {'last30Days': 3077}     False                 False
# ..                     ...       ...                   ...
# 208     {'last30Days': 64}     False                 False
# 207     {'last30Days': 42}     False                 False
# 182    {'last30Days': 545}     False                 False
# 172      {'last30Days': 1}     False                 False
# 158    {'last30Days': 135}     False                 False
#
#                                              heroImage  \
# 373  {'url': 'https://megapx-assets.dcard.tw/images...
# 228  {'url': 'https://megapx-assets.dcard.tw/images...
# 224  {'url': 'https://megapx-assets.dcard.tw/images...
# 217  {'url': 'https://megapx-assets.dcard.tw/images...
# 233  {'url': 'https://megapx-assets.dcard.tw/images...
# ..                                                 ...
# 208  {'url': 'https://megapx-assets.dcard.tw/images...
# 207  {'url': 'https://megapx-assets.dcard.tw/images...
# 182  {'url': 'https://megapx-assets.dcard.tw/images...
# 172                                                NaN
# 158  {'url': 'https://megapx-assets.dcard.tw/images...
#
#                                                   logo
# 373  {'url': 'https://megapx-assets.dcard.tw/images...
# 228  {'url': 'https://megapx-assets.dcard.tw/images...
# 224  {'url': 'https://megapx-assets.dcard.tw/images...
# 217  {'url': 'https://megapx-assets.dcard.tw/images...
# 233  {'url': 'https://megapx-assets.dcard.tw/images...
# ..                                                 ...
# 208  {'url': 'https://megapx-assets.dcard.tw/images...
# 207  {'url': 'https://megapx-assets.dcard.tw/images...
# 182  {'url': 'https://megapx-assets.dcard.tw/images...
# 172                                                NaN
# 158  {'url': 'https://megapx-assets.dcard.tw/images...
#
# [507 rows x 34 columns]
